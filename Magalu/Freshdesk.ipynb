# %%
import pandas as pd
from sqlalchemy import create_engine
import requests as r
import json

# %%
desk = 'donatelo.freshdesk.com'
desk_URL = 'https://' + desk
auth_deets = ('AYeCkCcm3yTLwvcEqc', 'x')
cat_query = r.get(desk_URL + "/api/v2/tickets", 
                  auth = auth_deets).content



df = pd.read_json(cat_query)

df.head(2)
# Out:
#   cc_emails fwd_emails reply_cc_emails ticket_cc_emails  fr_escalated   spam  \
# 0        []         []              []               []         False  False
# 1        []         []              []               []         False  False
#
#    email_config_id     group_id  priority  requester_id  ...  \
# 0              NaN  22000165881         4   22029153463  ...
# 1     2.200006e+10  22000165538         3   22026078366  ...
#
#                  due_by             fr_due_by  is_escalated  \
# 0  2021-12-30T18:03:51Z  2021-12-30T18:03:51Z         False
# 1  2021-12-30T18:03:17Z  2021-12-30T18:03:17Z         False
#
#                                        custom_fields  \
# 0  {'cf_para_atualizao_de_cadastro_de_cnpj_lembre...
# 1  {'cf_para_atualizao_de_cadastro_de_cnpj_lembre...
#
#                  created_at                updated_at  \
# 0 2021-12-29 18:03:51+00:00 2021-12-29 18:03:53+00:00
# 1 2021-12-29 18:03:16+00:00 2021-12-29 18:03:17+00:00
#
#   associated_tickets_count                 tags  nr_due_by  nr_escalated
# 0                      NaN     [NotificaçãoMLE]        NaN         False
# 1                      NaN  [Aberto por e-mail]        NaN         False
#
# [2 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 31 columns):
# cc_emails                   30 non-null object
# fwd_emails                  30 non-null object
# reply_cc_emails             29 non-null object
# ticket_cc_emails            29 non-null object
# fr_escalated                30 non-null bool
# spam                        30 non-null bool
# email_config_id             27 non-null float64
# group_id                    30 non-null int64
# priority                    30 non-null int64
# requester_id                30 non-null int64
# responder_id                10 non-null float64
# source                      30 non-null int64
# company_id                  8 non-null float64
# status                      30 non-null int64
# subject                     30 non-null object
# association_type            0 non-null float64
# support_email               8 non-null object
# to_emails                   8 non-null object
# product_id                  21 non-null float64
# id                          30 non-null int64
# type                        30 non-null object
# due_by                      30 non-null object
# fr_due_by                   30 non-null object
# is_escalated                30 non-null bool
# custom_fields               30 non-null object
# created_at                  30 non-null datetime64[ns, UTC]
# updated_at                  30 non-null datetime64[ns, UTC]
# associated_tickets_count    0 non-null float64
# tags                        30 non-null object
# nr_due_by                   0 non-null float64
# nr_escalated                30 non-null bool
# dtypes: bool(4), datetime64[ns, UTC](2), float64(7), int64(6), object(12)
# memory usage: 6.6+ KB
