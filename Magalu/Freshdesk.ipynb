# %%
import pandas as pd
from pandas import json_normalize
from sqlalchemy import create_engine
import requests as r
import json
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-14-205cf69fc58e> in <module>
#       1 import pandas as pd
# ----> 2 from pandas import json_normalize
#       3 from sqlalchemy import create_engine
#       4 import requests as r
#       5 import json
#
# ImportError: cannot import name 'json_normalize' from 'pandas' (C:\ProgramData\Anaconda3\lib\site-packages\pandas\__init__.py)

# %%
desk = 'donatelo.freshdesk.com'
desk_URL = 'https://' + desk
auth_deets = ('AYeCkCcm3yTLwvcEqc', 'x')
cat_query = r.get(desk_URL + "/api/v2/tickets", 
                  auth = auth_deets).content



df = pd.read_json(cat_query)

df.head(2)
# Out:
#   cc_emails fwd_emails reply_cc_emails ticket_cc_emails  fr_escalated   spam  \
# 0        []         []              []               []         False  False
# 1        []         []              []               []         False  False
#
#    email_config_id     group_id  priority  requester_id  ...  \
# 0      22000058647  22000164717         1   22027101600  ...
# 1      22000058647  22000164717         1   22027101600  ...
#
#                  due_by             fr_due_by  is_escalated  \
# 0  2022-02-14T12:10:31Z  2022-02-14T12:10:31Z         False
# 1  2022-02-14T12:10:28Z  2022-02-14T12:10:28Z         False
#
#                                        custom_fields  \
# 0  {'cf_para_atualizao_de_cadastro_de_cnpj_lembre...
# 1  {'cf_para_atualizao_de_cadastro_de_cnpj_lembre...
#
#                  created_at                updated_at  \
# 0 2022-02-08 12:10:29+00:00 2022-02-08 12:10:31+00:00
# 1 2022-02-08 12:10:27+00:00 2022-02-08 12:10:28+00:00
#
# ...

# %%
campos_personalizados = json_normalize(df['custom_fields'])
campos_personalizados.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-13b65da0bdfb> in <module>
# ----> 1 campos_personalizados = json_normalize(df['custom_fields'])
#       2 campos_personalizados.head()
#
# NameError: name 'json_normalize' is not defined

# %%
df.to_csv(r'C:\Users\mo_duarte\Desktop\Marketplace\tabela_freshdesk_v2.csv')

# %%
conda update pandas
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\Anaconda3
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     async_generator-1.10       |     pyhd3eb1b0_0          23 KB
#     attrs-21.4.0               |     pyhd3eb1b0_0          51 KB
#     backcall-0.2.0             |     pyhd3eb1b0_0          13 KB
#     backports-1.1              |     pyhd3eb1b0_0           4 KB
#     backports.functools_lru_cache-1.6.4|     pyhd3eb1b0_0           9 KB
#     backports.tempfile-1.0     |     pyhd3eb1b0_1          11 KB
#     beautifulsoup4-4.10.0      |     pyh06a4308_0          85 KB
#     ca-certificates-2021.10.26 |       haa95532_4         116 KB
#     certifi-2021.10.8          |   py38haa95532_2         152 KB
#     cffi-1.15.0                |   py38h2bbff1b_1         223 KB
# ...
